# %% [markdown]
# # Computational notebook

# %% [markdown]
# ### Вычисление числа pi с помощью метода Монте-Карло

# %% [markdown]
# #### Формулы
# - Площадь квадрата: $s = (2 r)^2$
# - Площадь круга: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ![Дротики][def]
#
# [def]: https://raw.githubusercontent.com/coderefinery/jupyter/main/example/darts.svg

# %% [markdown]
# ### Импортируем модули

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Инициализируем количество точек

# %%
num_points = 5000

# %% [markdown]
# ### Броски дротиков

# %%
points = []
hits = 0
for _ in range (num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x,y, "blue"))
    else:
        points.append((x,y, "yellow"))

# %% [markdown]
# ### Построение графика

# %%
x, y, colors = zip(*points)
fig, ax = plt.subplots()
fig.set_size_inches(6.0,6.0)
ax.scatter(x,y, c = colors)

fraction = hits / num_points
print('Число pi = ' + str(4 * fraction))
# Out:
# Число pi = 3.156

# %% [markdown]
# ### Зависимости

# %%
# !python -m pip install pandas matplotlib
# !python -m pip install pandas matplotlib seaborn
# !python -m pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.5 MB 10.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 25.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 25.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 25.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 6.9 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# ...

# %%
# %matplotlib inline
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_theme(style="whitegrid")
from itertools import cycle

# %% [markdown]
# ## Метод Монте-Карло через функции

# %%
from matplotlib import pyplot 
import random
from ipywidgets import interact, widgets

# %%
# %matplotlib inline


def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)

# %% [markdown]
# ## Виджеты

# %%
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100,
value=1000))
